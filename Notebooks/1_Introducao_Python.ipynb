# %% [markdown]
# ###Primeiros comandos em Python

# %%
print("Olá Mundo!")
# Out:
# Olá Mundo!

# %%
print("É fácil aprender Python!")
# Out:
# É fácil aprender Python!

# %%
"Estou aprendendo Python"
# Out:
# 'Estou aprendendo Python'

# %%
# Esse é um comentário em Python

# %%
# Soma
1 + 1
# Out:
# 2

# %%
# Subtração
10 - 2
# Out:
# 8

# %%
#Multiplicação
2 * 2
# Out:
# 4

# %%
#Divisão
10/2
# Out:
# 5.0

# %%
# Variáveis
a = 4
b = 6

# %%
a + b
# Out:
# 10

# %%
# Criando uma variável do tipo string
frase = "Python para análise de dados"

# %%
# Primeira posição da frase
frase[0]
# Out:
# 'P'

# %%
# Fatiamento
frase[0:10]
# Out:
# 'Python par'

# %%
frase[10:]
# Out:
# 'a análise de dados'

# %%
frase[:17]
# Out:
# 'Python para análi'

# %%
# Contar palavras
frase.count("dados")
# Out:
# 1

# %%
# Transformar todas as letras para minúsculo
frase.lower()
# Out:
# 'python para análise de dados'

# %%
# Transformar todas as letras para maiúscula
frase = frase.upper()

# %%
# Substituir palavra
frase.replace("Python","Frases")
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
frase
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'
